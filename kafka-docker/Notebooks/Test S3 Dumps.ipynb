# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.42.60-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.43.0,>=1.42.60 (from boto3)
#   Downloading botocore-1.42.60-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in e:\anaconda\lib\site-packages (from boto3) (1.0.1)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in e:\anaconda\lib\site-packages (from botocore<1.43.0,>=1.42.60->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in e:\anaconda\lib\site-packages (from botocore<1.43.0,>=1.42.60->boto3) (2.5.0)
# Requirement already satisfied: six>=1.5 in e:\anaconda\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.60->boto3) (1.17.0)
# Downloading boto3-1.42.60-py3-none-any.whl (140 kB)
# Downloading botocore-1.42.60-py3-none-any.whl (14.6 MB)
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/14.6 MB 2.4 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.6/14.6 MB 2.8 MB/s eta 0:00:05
#    ------- -------------------------------- 2.6/14.6 MB 3.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.9/14.6 MB 4.1 MB/s eta 0:00:03
#    --------------- ------------------------ 5.5/14.6 MB 4.8 MB/s eta 0:00:02
#    -------------------- ------------------- 7.6/14.6 MB 5.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 8.7/14.6 MB 5.6 MB/s eta 0:00:02
#    ------------------------- -------------- 9.4/14.6 MB 5.4 MB/s eta 0:00:01
#    --------------------------- ------------ 10.2/14.6 MB 5.2 MB/s eta 0:00:01
#    ------------------------------ --------- 11.0/14.6 MB 4.9 MB/s eta 0:00:01
#    ------------------------------ --------- 11.3/14.6 MB 4.8 MB/s eta 0:00:01
#    -------------------------------- ------- 12.1/14.6 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 12.6/14.6 MB 4.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.1/14.6 MB 4.3 MB/s eta 0:00:01
#    ------------------------------------- -- 13.6/14.6 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  14.4/14.6 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 14.6/14.6 MB 4.1 MB/s  0:00:03
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Installing collected packages: botocore, s3transfer, boto3
#
#   Attempting uninstall: botocore
#
#     Found existing installation: botocore 1.40.46
#
#    ---------------------------------------- 0/3 [botocore]
#     Uninstalling botocore-1.40.46:
#    ---------------------------------------- 0/3 [botocore]
#       Successfully uninstalled botocore-1.40.46
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ------------- -------------------------- 1/3 [s3transfer]
#    -------------------------- ------------- 2/3 [boto3]
#    -------------------------- ------------- 2/3 [boto3]
#    ---------------------------------------- 3/3 [boto3]
#
# Successfully installed boto3-1.42.60 botocore-1.42.60 s3transfer-0.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.25.0 requires botocore<1.40.50,>=1.40.46, but you have botocore 1.42.60 which is incompatible.

# %%
import requests
import json
import boto3

# %%
url = "https://api.openaq.org/v3/locations"
headers = {
    "X-API-Key": "MY_API_KEY"
}

# %%
response = requests.get(url, headers=headers)
data = response.json()

# %%
filename = "locations.json"

with open(filename, "w") as f:
    json.dump(data, f) #serializes json and stores it in the file f

print("File saved locally")
# Out:
# File saved locally

# %%
s3 = boto3.client(
    "s3",
    aws_access_key_id="AWS_ACCESS_KEY",
    aws_secret_access_key="AWS_SECRET_KEY",
    region_name="REGION"
)

bucket_name = "openaq-project-dm"

# %%
s3.upload_file(
    "openaq_locations.json",
    bucket_name,
    "raw/locations.json"
)

print("Uploaded to S3")
# Out:
# Uploaded to S3
