-- %%
--CREATE CATALOG IF NOT EXISTS OpenAQ;

--USE CATALOG OpenAQ;

/*CREATE SCHEMA IF NOT EXISTS openaq.bronze;
CREATE SCHEMA IF NOT EXISTS openaq.silver;
CREATE SCHEMA IF NOT EXISTS openaq.gold;*/

--SHOW DATABASES FROM openaq;
